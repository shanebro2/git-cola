# %% [markdown]
# <a href="https://colab.research.google.com/github/shanebro2/git-cola/blob/master/2_diff_text_files_compare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = open('ATL VM Names.txt','r')
b = open('IESP VM Names.txt','r')
name = list(a)
for line in b:
  if line in name:
    print("match found", line)
  else:
    print("**match NOT found**", line)
# Out:
# match found atladasfep001
#
# match found atlaimmapp
#
# match found atlaimmdb
#
# match found atlaimmetl
#
# match found atlaimmgis
#
# match found atlbsmcon001
#
# match found atlbsmdb001
#
# match found atlbsmdp001
#
# match found atlbsmgw001
#
# **match NOT found** atlcmdview001
#
# match found atldc001
#
# match found atldc002
#
# **match NOT found** atldesktop1 - 17
#
# match found atldhcp001
#
# match found atldhcp002
#
# **match NOT found** atldtapfep001
#
# match found atlhpova001
#
# match found atliamcdp01
#
# match found atliamcdp01
#
# match found atliamcdp02
#
# match found atliamcdp02
#
# match found atliamds01
#
# match found atliamds01
#
# match found atliames01
#
# match found atliames01
#
# match found atliamocsp01
#
# match found atliamocsp01
#
# match found atliamocsp02
#
# match found atliamocsp02
#
# match found atliamra01
#
# match found atliamra01
#
# match found atliamrepo01
#
# match found atliamrepo01
#
# match found atliamsts01
#
# ...
